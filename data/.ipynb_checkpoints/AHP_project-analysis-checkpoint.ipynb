# %%
import pandas as pd

# %%
df = pd.read_csv('csv/Affordable_Housing_Production_by_Project_20240115.csv')

# %%
df.head()
# Out:
#    Project ID                    Project Name                Program Group  \
# 0       44218  MEC E. 125TH ST. PARCEL B WEST  Multifamily Finance Program
# 1       44223        ROCHESTER SUYDAM PHASE 1  Multifamily Finance Program
# 2       44225         Brook Avenue Apartments  Multifamily Finance Program
# 3       44230    Mermaid  / West. 16th Street          Small Homes Program
# 4       44239         Home for Harlem Dowling  Multifamily Finance Program
#
#   Project Start Date Project Completion Date Extended Affordability Only  \
# 0         12/31/2018              02/16/2022                          No
# 1         06/30/2021                     NaN                          No
# 2         06/27/2014              12/28/2016                          No
# 3         06/30/2015              07/21/2017                          No
# 4         06/30/2014              12/29/2016                          No
#
#   Prevailing Wage Status Planned Tax Benefit  Extremely Low Income Units  \
# ...

# %%
df.describe()
# Out:
#          Project ID  Extremely Low Income Units  Very Low Income Units  \
# count   4150.000000                 4150.000000            4150.000000
# mean   66010.368675                    9.738072              16.586747
# std     7173.246611                   39.089808             213.252870
# min    44218.000000                    0.000000               0.000000
# 25%    61444.500000                    0.000000               0.000000
# 50%    68353.500000                    0.000000               0.000000
# 75%    71719.500000                    0.000000               0.000000
# max    74681.000000                  572.000000           11413.000000
#
#        Low Income Units  Moderate Income Units  Middle Income Units  \
# count       4150.000000            4150.000000          4150.000000
# mean          20.786265               3.580964             6.856867
# std          101.354159              26.762897            74.422259
# ...
