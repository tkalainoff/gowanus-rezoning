# %%
import pandas as pd

# %%
df = pd.read_csv('csv/Affordable_Housing_Production_by_Building_20240115.csv')

# %%
df.head()
# Out:
#    Project ID                  Project Name Project Start Date  \
# 0       71425             1984 THIRD AVENUE         09/29/2023
# 1       74523                  CONFIDENTIAL         09/29/2023
# 2       74526                  CONFIDENTIAL         09/29/2023
# 3       74531                  CONFIDENTIAL         09/29/2023
# 4       74558  352 MEEKER AVENUE APARTMENTS         09/29/2023
#
#   Project Completion Date  Building ID Number         Street    Borough  \
# 0                     NaN    1010284.0   1984       3 AVENUE  Manhattan
# 1              09/29/2023          NaN   ----           ----      Bronx
# 2              09/29/2023          NaN   ----           ----      Bronx
# 3              09/29/2023          NaN   ----           ----      Bronx
# 4                     NaN    1010119.0    352  MEEKER AVENUE   Brooklyn
#
#    Postcode           BBL  ...  2-BR Units 3-BR Units  4-BR Units 5-BR Units  \
# ...

# %%
df.describe()
# Out:
#          Project ID   Building ID      Postcode           BBL           BIN  \
# count   6996.000000  5.573000e+03   5527.000000  5.466000e+03  5.466000e+03
# mean   64107.856061  5.625925e+05  10796.604668  2.481691e+09  2.600794e+06
# std     7659.507927  3.968207e+05    510.851423  9.432682e+08  1.022559e+06
# min    44218.000000  3.750000e+02  10001.000000  1.000638e+09  1.000000e+06
# 25%    58608.000000  1.156920e+05  10454.000000  2.026143e+09  2.004307e+06
# 50%    66670.000000  7.239790e+05  11205.000000  3.012055e+09  3.008367e+06
# 75%    70001.000000  9.722090e+05  11221.000000  3.038218e+09  3.342618e+06
# max    74681.000000  1.010410e+06  11694.000000  5.031570e+09  5.171901e+06
#
#        Council District     Latitude    Longitude  Latitude (Internal)  \
# count       6989.000000  5527.000000  5527.000000          5460.000000
# mean          26.245958    40.742846   -73.919283            40.743024
# ...
